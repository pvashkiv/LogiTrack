# %% [markdown]
# # 📦 Аналіз логістичних даних
# # Цей ноутбук аналізує дані перевезень: середні значення, найвигідніші маршрути, найдовші по відстані та будує карту оптимальних маршрутів.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import folium
from datetime import datetime
from geopy.geocoders import Nominatim
from tqdm import tqdm
import time
import openrouteservice
from openrouteservice import convert
# Out:
# /Users/pavlovaskiv/PycharmProjects/LogiTrack/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# # 📂 Завантаження Excel-файлу
# # Ми зчитуємо файл `Loads 2024.xlsx` з аркуша `DATA`.

# %%
ORS_API_KEY = "eyJvcmciOiI1YjNjZTM1OTc4NTExMTAwMDFjZjYyNDgiLCJpZCI6IjRkNDI3MjgwYTJjZDRhYzNhMzVlZjM5ZTY5NmM2N2YyIiwiaCI6Im11cm11cjY0In0="

df = pd.read_excel("Loads 2024.xlsx", sheet_name="DATA")
df.head()
# Out:
#       start       end    Type  Load # Type of load     Status        RC  \
# 0  1/2/2024  1/8/2024    CONS  T38701          DRY     BILLED  52288462
# 1  1/2/2024  1/8/2024  CANCEL  T38702          DRY  AVAILABLE  28329665
# 2  1/2/2024  1/8/2024     OTR  T38703          DRY     BILLED   9114765
# 3  1/2/2024  1/8/2024     OTR  T38704           TC     BILLED  10220974
# 4  1/2/2024  1/8/2024     OTR  T38705           TC     BILLED  11857671
#
#         Broker         From City From State        To City To State Occupancy  \
# 0         ECHO            GURNEE         IL         SPARKS       NV        TL
# 1       COYOTE  RANCHO DOMINGUEZ         CA         DEKALB       IL        TL
# 2    PAM TRANS          OLD FORT         OH   MURFREESBORO       TN        TL
# 3  SURGE TRANS            AURORA         IL  CENTER VALLEY       PA        TL
# 4          TTC            EDMOND         OK     JANESVILLE       WI        TL
#
#   Pallets           Material Temperature Type of transport    Rate   Miles  \
# 0      22  Huel (Foodstuffs)         DRY              ROAD  4000.0  1930.0
# 1      25                NaN         DRY              ROAD  3400.0  2114.0
# 2     NaN               FOOD         DRY              ROAD  1600.0   503.0
# 3     NaN   GROCERY PRODUCTS         RPB              ROAD  2800.0   772.0
# 4     NaN        liquid eggs      38-40F              ROAD  2400.0   812.0
#
#       RPM
# 0  2.0725
# 1  1.6083
# 2  3.1809
# 3  3.6269
# 4  2.9557

# %% [markdown]
# # 🧹 Очищення та передобробка
# # Очищаємо дані від пропущених значень і рахуємо тривалість доставки.

# %%
df = df.dropna(subset=["Rate", "Miles", "From City", "To City", "Rate", "RPM", "start", "end"])
df["Miles"] = pd.to_numeric(df["Miles"], errors='coerce')
df["Rate"] = pd.to_numeric(df["Rate"], errors='coerce')
df["RPM"] = pd.to_numeric(df["RPM"], errors='coerce')
df["start"] = pd.to_datetime(df["start"])
df["end"] = pd.to_datetime(df["end"])
df["delivery_time_days"] = (df["end"] - df["start"]).dt.days

# %% [markdown]
# # 📊 Розрахунок аналітики
# # Шукаємо середні значення, найдовший маршрут та найбільш прибутковий.

# %%
longest_trip = df.loc[df["Miles"].idxmax()]
most_profitable_trip = df.loc[df["RPM"].idxmax()]
avg_stats = {
    "Середній час доставки (днів)": df["delivery_time_days"].mean(),
    "Середня відстань (милі)": df["Miles"].mean(),
    "Середня оплата (Rate)": df["Rate"].mean(),
    "Середній RPM": df["RPM"].mean(),
    "Середня кількість палет": pd.to_numeric(df["Pallets"], errors='coerce').mean()
}

# %%
# Середні значення у вигляді таблиці
pd.DataFrame(avg_stats, index=["Значення"]).T
# Out:
#                                  Значення
# Середній час доставки (днів)     6.021605
# Середня відстань (милі)       1525.715057
# Середня оплата (Rate)         2665.071688
# Середній RPM                     2.114387
# Середня кількість палет         28.138533

# %%
# Найвигідніший маршрут
most_profitable_trip = df.loc[df["RPM"].idxmax()]
most_profitable_trip[["From City", "To City", "Miles", "Rate", "RPM"]].to_frame(name="Найвигідніший маршрут")
# Out:
#           Найвигідніший маршрут
# From City              STOCKTON
# To City                STOCKTON
# Miles                       2.0
# Rate                     1200.0
# RPM                       600.0

# %%
# Найдовший маршрут
longest_trip = df.loc[df["Miles"].idxmax()]
longest_trip[["From City", "To City", "Miles", "Rate", "RPM"]].to_frame(name="Найдовший маршрут")
# Out:
#           Найдовший маршрут
# From City           ALAMEDA
# To City       VAN BUREN TWP
# Miles               23700.0
# Rate                 2000.0
# RPM                  0.0844

# %%
# Топ  найдорожчих маршрутів
top_by_rate = df.sort_values(by="Rate", ascending=False).head(5)
top_by_rate[["From City", "To City", "Rate", "Miles", "RPM"]]
# Out:
#          From City       To City       Rate   Miles      RPM
# 8083     PATTERSON       LIVONIA  8850.0000  4237.0   2.0887
# 404         OXNARD  MELROSE PARK  8423.6504  2062.0   4.0852
# 713         OXNARD  MELROSE PARK  7973.6499  2062.0   3.8669
# 3301        NORMAL      BELLEVUE  7800.0000   388.0  20.1031
# 5798  BALDWIN PARK     OAK CREEK  7550.0000  2221.0   3.3994
# ...            ...           ...        ...     ...      ...
# 2861    GROVE CITY       HAYWARD  5300.0000  2437.0   2.1748
# 5943   SANRA MARIA  MELROSE PARK  5300.0000  2290.0   2.3144
# 6324    ROMEOVILLE          RENO  5297.4600  1903.0   2.7837
# 7742     NEW PARIS          RENO  5282.5000  2023.0   2.6112
# 6270    ROMEOVILLE          RENO  5278.6400  1903.0   2.7739
#
# [100 rows x 5 columns]

# %%
# Топ маршрутів з найнижчим RPM
top_cheapest = df[df["Rate"] > 0].sort_values(by="RPM").head(5)
top_cheapest[["From City", "To City", "Rate", "Miles", "RPM"]]
# Out:
#          From City        To City    Rate  Miles  RPM
# 1905       Markham        Concord   500.0    NaN  0.0
# 845       SAN JOSE   GRAND RAPIDS  1880.0    NaN  0.0
# 952   CAROL STREAM  GRAND PRAIRIE  2800.0    NaN  0.0
# 7120      SAN JOSE      DALY CITY   450.0    NaN  0.0
# 137     WASHINGTON       LOCKPORT   900.0    NaN  0.0

# %% [markdown]
# # 🗺️ Побудова карти маршрутів (опціонально)
# # Цей блок виконує геокодування та побудову маршрутів. **Розкоментуй для виконання.**

# %%
geolocator = Nominatim(user_agent="logistics-map")
ors_client = openrouteservice.Client(key=ORS_API_KEY)
m = folium.Map(location=[39.5, -98.35], zoom_start=4)

def geocode(city, state):
    try:
        location = geolocator.geocode(f"{city}, {state}")
        if location:
            return (location.latitude, location.longitude)
    except:
        return None

sample_df = df.head(5)

for _, row in tqdm(sample_df.iterrows(), total=sample_df.shape[0]):
    from_coords = geocode(row["From City"], row["From State"])
    to_coords = geocode(row["To City"], row["To State"])
    time.sleep(1)

    if from_coords and to_coords:
        try:
            coords = [(from_coords[1], from_coords[0]), (to_coords[1], to_coords[0])]
            route = ors_client.directions(coords)
            decoded = convert.decode_polyline(route['routes'][0]['geometry'])
            folium.PolyLine(
                locations=[(lat, lon) for lon, lat in decoded["coordinates"]],
                tooltip=f"{row['From City']} → {row['To City']} ({row['Miles']} mi)",
                color="blue"
            ).add_to(m)
            folium.Marker(location=from_coords, popup="From: " + row["From City"], icon=folium.Icon(color='green')).add_to(m)
            folium.Marker(location=to_coords, popup="To: " + row["To City"], icon=folium.Icon(color='red')).add_to(m)
        except Exception as e:
            print(f"❌ Помилка маршруту: {e}")

m
# Out:
# 100%|██████████| 5/5 [00:17<00:00,  3.41s/it]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ce484b008ccd57d9e88380442950b4dc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ce484b008ccd57d9e88380442950b4dc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ce484b008ccd57d9e88380442950b4dc = L.map(
#                 &quot;map_ce484b008ccd57d9e88380442950b4dc&quot;,
#                 {
#                     center: [39.5, -98.35],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e7b8a524ba5b9ee195639e7141b81956 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e7b8a524ba5b9ee195639e7141b81956.addTo(map_ce484b008ccd57d9e88380442950b4dc);
#
#
#             var poly_line_8aa3717c2c87e938dfdee7a36874a2a4 = L.polyline(
#                 [[33.85947, -118.21647], [33.85929, -118.21656], [33.85858, -118.21681], [33.85808, -118.21698], [33.85773, -118.21717], [33.85974, -118.21711], [33.8608, -118.21708], [33.86109, -118.21704], [33.86138, -118.21698], [33.8627, -118.21653], [33.86324, -118.21639], [33.86521, -118.21604], [33.86581, -118.21598], [33.86639, -118.2159], [33.86718, -118.21586], [33.86793, -118.2159], [33.86855, -118.21592], [33.8698, -118.21611], [33.8699, -118.21614], [33.87058, -118.21627], [33.87139, -118.21646], [33.87142, -118.21661], [33.87145, -118.21681], [33.8715, -118.21695], [33.87157, -118.21706], [33.87165, -118.21714], [33.87173, -118.21718], [33.87182, -118.2172], [33.87201, -118.21716], [33.87215, -118.21705], [33.87221, -118.21695], [33.87308, -118.2152], [33.87315, -118.21495], [33.87324, -118.21449], [33.87328, -118.21403], [33.87344, -118.21142], [33.87347, -118.20933], [33.87347, -118.20835], [33.87343, -118.20788], [33.87337, -118.2074